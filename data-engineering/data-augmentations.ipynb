# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip combined.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: sad/Training_80971452.jpg
#  extracting: sad/Training_80974723.jpg
#  extracting: sad/Training_80981346.jpg
#  extracting: sad/Training_81008287.jpg
#  extracting: sad/Training_81013514.jpg
#  extracting: sad/Training_81039583.jpg
#  extracting: sad/Training_81048535.jpg
#  extracting: sad/Training_81053420.jpg
#  extracting: sad/Training_81075199.jpg
#  extracting: sad/Training_81097657.jpg
#  extracting: sad/Training_81101893.jpg
#  extracting: sad/Training_81104314.jpg
#  extracting: sad/Training_81116022.jpg
#  extracting: sad/Training_81128509.jpg
#  extracting: sad/Training_81161441.jpg
#  extracting: sad/Training_81163506.jpg
#  extracting: sad/Training_81184858.jpg
#  extracting: sad/Training_81195052.jpg
#  extracting: sad/Training_81205963.jpg
#  extracting: sad/Training_81230199.jpg
#  extracting: sad/Training_81237423.jpg
#  extracting: sad/Training_81241836.jpg
#  extracting: sad/Training_81243969.jpg
# ...

# %%
# !pip install -U albumentations

# %%
import albumentations as A
import cv2
import os
import numpy as np
import random

# %%
classes = ["angry","disgust","fear","happy","neutral","sad","surprise"]

# %%
maxSize = len(os.listdir("happy"))

# %%
# root_output_dir = os.path.join("/content/drive/MyDrive/", "combined-images")

# %%
transform = A.Compose([
    A.HorizontalFlip(p=0.7),
    A.SafeRotate(p=0.7, limit=30),
    A.RandomScale(p=0.7, scale_limit=(0.0, 0.55)),
    A.ShiftScaleRotate(p=0.7, border_mode=cv2.BORDER_REPLICATE, scale_limit=(0,0), rotate_limit=(0,0), shift_limit=(-0.2, 0.2)),
    A.RandomBrightnessContrast(p=0.7, brightness_limit=(-0.3, 0.3), contrast_limit=(-0.3, 0.3)),
    A.CenterCrop(p=1, width=48, height=48),
])

# %%
for folder_name in classes:
    files = os.listdir(folder_name)
    num_files = len(files)
    total_new = maxSize - num_files
    indices = np.arange(len(files))
    bucket = set()
    img_counter = 0
    for i in range(total_new):
        if(len(bucket) == num_files):
            bucket.clear()
        file_i = random.choice(indices)
        while(file_i in bucket):
            file_i = random.choice(indices, 1)
        file_name = files[file_i]
        image = cv2.imread(os.path.join(folder_name, file_name))
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        transformed = transform(image=image)
        transformed_image = transformed["image"]
        # output_dir = os.path.join(root_output_dir, folder_name)
        output_dir = os.path.join(folder_name, folder_name + str(img_counter) + ".jpg")
        cv2.imwrite(output_dir, transformed_image)
        img_counter += 1
    print(folder_name + " files completed: " + str(len(os.listdir(folder_name))))
# Out:
# angry files completed: 8989
# disgust files completed: 8989
# fear files completed: 8989
# happy files completed: 8989
# neutral files completed: 8989
# sad files completed: 8989
# surprise files completed: 8989

# %%
# !zip -r angry.zip angry/
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: angry/Training_66823441.jpg (stored 0%)
#   adding: angry/Training_37957889.jpg (stored 0%)
#   adding: angry/angry2904.jpg (deflated 10%)
#   adding: angry/Training_99744727.jpg (stored 0%)
#   adding: angry/PrivateTest_35759444.jpg (stored 0%)
#   adding: angry/Training_96313559.jpg (stored 0%)
#   adding: angry/angry3101.jpg (deflated 8%)
#   adding: angry/Training_25823142.jpg (stored 0%)
#   adding: angry/Training_31705730.jpg (stored 0%)
#   adding: angry/PrivateTest_39390808.jpg (stored 0%)
#   adding: angry/angry590.jpg (deflated 9%)
#   adding: angry/Training_36365391.jpg (stored 0%)
#   adding: angry/Training_70299484.jpg (stored 0%)
#   adding: angry/Training_38970819.jpg (stored 0%)
#   adding: angry/Training_84166964.jpg (stored 0%)
#   adding: angry/angry2268.jpg (deflated 11%)
#   adding: angry/angry888.jpg (deflated 10%)
#   adding: angry/Training_52328613.jpg (stored 0%)
# ...

# %%
# !zip -r disgust.zip disgust/
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: disgust/disgust1547.jpg (deflated 9%)
#   adding: disgust/disgust3557.jpg (deflated 11%)
#   adding: disgust/Training_52480931.jpg (stored 0%)
#   adding: disgust/disgust1222.jpg (deflated 12%)
#   adding: disgust/disgust4424.jpg (deflated 13%)
#   adding: disgust/disgust2705.jpg (deflated 12%)
#   adding: disgust/disgust2543.jpg (deflated 13%)
#   adding: disgust/disgust6816.jpg (deflated 10%)
#   adding: disgust/disgust1922.jpg (deflated 13%)
#   adding: disgust/Training_31585404.jpg (stored 0%)
#   adding: disgust/disgust2495.jpg (deflated 16%)
#   adding: disgust/disgust1415.jpg (deflated 12%)
#   adding: disgust/disgust7170.jpg (deflated 11%)
#   adding: disgust/disgust5952.jpg (deflated 11%)
#   adding: disgust/disgust3447.jpg (deflated 11%)
#   adding: disgust/disgust5146.jpg (deflated 10%)
#   adding: disgust/disgust2844.jpg (deflated 10%)
#   adding: disgust/disgust668.jpg (deflated 10%)
# ...

# %%
# !zip -r fear.zip fear/
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: fear/fear3024.jpg (deflated 11%)
#   adding: fear/Training_75260133.jpg (stored 0%)
#   adding: fear/PrivateTest_13213011.jpg (stored 0%)
#   adding: fear/Training_9848254.jpg (stored 0%)
#   adding: fear/Training_64175105.jpg (stored 0%)
#   adding: fear/fear531.jpg (deflated 12%)
#   adding: fear/fear1542.jpg (deflated 11%)
#   adding: fear/fear3025.jpg (deflated 11%)
#   adding: fear/PrivateTest_86867911.jpg (stored 0%)
#   adding: fear/Training_12084676.jpg (stored 0%)
#   adding: fear/Training_23028959.jpg (stored 0%)
#   adding: fear/Training_86666905.jpg (stored 0%)
#   adding: fear/Training_90938861.jpg (stored 0%)
#   adding: fear/fear2681.jpg (deflated 11%)
#   adding: fear/Training_68596982.jpg (stored 0%)
#   adding: fear/Training_67224906.jpg (stored 0%)
#   adding: fear/Training_88691232.jpg (stored 0%)
#   adding: fear/PublicTest_1833321.jpg (stored 0%)
#   adding: fear/PublicTest_44457627.jpg (stored 0%)
# ...

# %%
# !zip -r happy.zip happy/
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: happy/Training_63005452.jpg (stored 0%)
#   adding: happy/Training_39084146.jpg (stored 0%)
#   adding: happy/Training_16325840.jpg (stored 0%)
#   adding: happy/Training_83862960.jpg (stored 0%)
#   adding: happy/Training_23756252.jpg (stored 0%)
#   adding: happy/Training_15998976.jpg (stored 0%)
#   adding: happy/PublicTest_16904324.jpg (stored 0%)
#   adding: happy/Training_38159315.jpg (stored 0%)
#   adding: happy/PrivateTest_20254872.jpg (stored 0%)
#   adding: happy/Training_38212949.jpg (stored 0%)
#   adding: happy/Training_40338984.jpg (stored 0%)
#   adding: happy/Training_73279136.jpg (stored 0%)
#   adding: happy/Training_31025537.jpg (stored 0%)
#   adding: happy/Training_51719990.jpg (stored 0%)
#   adding: happy/Training_63340234.jpg (stored 0%)
#   adding: happy/Training_34727870.jpg (stored 0%)
#   adding: happy/Training_60579409.jpg (stored 0%)
#   adding: happy/Training_69816268.jpg (stored 0%)
# ...

# %%
# !zip -r neutral.zip neutral/
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: neutral/neutral2362.jpg (deflated 11%)
#   adding: neutral/neutral858.jpg (deflated 10%)
#   adding: neutral/Training_20632493.jpg (stored 0%)
#   adding: neutral/Training_98881815.jpg (stored 0%)
#   adding: neutral/Training_66574797.jpg (stored 0%)
#   adding: neutral/Training_82153895.jpg (stored 0%)
#   adding: neutral/Training_89008898.jpg (stored 0%)
#   adding: neutral/PrivateTest_11239107.jpg (stored 0%)
#   adding: neutral/neutral2213.jpg (deflated 10%)
#   adding: neutral/Training_19316070.jpg (stored 0%)
#   adding: neutral/PrivateTest_43252230.jpg (stored 0%)
#   adding: neutral/Training_64786684.jpg (stored 0%)
#   adding: neutral/neutral263.jpg (deflated 10%)
#   adding: neutral/Training_25312384.jpg (stored 0%)
#   adding: neutral/neutral1279.jpg (deflated 12%)
#   adding: neutral/PrivateTest_97569291.jpg (stored 0%)
#   adding: neutral/PublicTest_65538215.jpg (stored 0%)
# ...

# %%
# !zip -r sad.zip sad/
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: sad/PrivateTest_37093219.jpg (stored 0%)
#   adding: sad/sad1146.jpg (deflated 10%)
#   adding: sad/Training_89185756.jpg (stored 0%)
#   adding: sad/PublicTest_48893233.jpg (stored 0%)
#   adding: sad/PublicTest_22967870.jpg (stored 0%)
#   adding: sad/sad1650.jpg (deflated 13%)
#   adding: sad/sad1278.jpg (deflated 9%)
#   adding: sad/sad2246.jpg (deflated 9%)
#   adding: sad/Training_67985555.jpg (stored 0%)
#   adding: sad/PublicTest_3039573.jpg (stored 0%)
#   adding: sad/sad1735.jpg (deflated 12%)
#   adding: sad/Training_71898542.jpg (stored 0%)
#   adding: sad/sad1666.jpg (deflated 11%)
#   adding: sad/Training_18143535.jpg (stored 0%)
#   adding: sad/Training_69814836.jpg (stored 0%)
#   adding: sad/Training_75262711.jpg (stored 0%)
#   adding: sad/Training_97187547.jpg (stored 0%)
#   adding: sad/Training_78142280.jpg (stored 0%)
#   adding: sad/Training_38677003.jpg (stored 0%)
# ...

# %%
# !zip -r surprise.zip surprise/
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: surprise/surprise4018.jpg (deflated 9%)
#   adding: surprise/surprise4434.jpg (deflated 11%)
#   adding: surprise/surprise2213.jpg (deflated 14%)
#   adding: surprise/Training_66629295.jpg (stored 0%)
#   adding: surprise/surprise1842.jpg (deflated 10%)
#   adding: surprise/Training_51672562.jpg (stored 0%)
#   adding: surprise/surprise1846.jpg (deflated 12%)
#   adding: surprise/Training_4544515.jpg (stored 0%)
#   adding: surprise/Training_1817980.jpg (stored 0%)
#   adding: surprise/surprise2024.jpg (deflated 14%)
#   adding: surprise/Training_99604118.jpg (stored 0%)
#   adding: surprise/PrivateTest_63231524.jpg (stored 0%)
#   adding: surprise/surprise2077.jpg (deflated 10%)
#   adding: surprise/surprise1999.jpg (deflated 11%)
#   adding: surprise/Training_45586531.jpg (stored 0%)
#   adding: surprise/surprise2156.jpg (deflated 9%)
#   adding: surprise/surprise401.jpg (deflated 11%)
# ...

# %%
for folder_name in classes:
